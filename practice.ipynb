# %% [markdown]
# # python 边学边练

# %% [markdown]
# ## 迭代器
#
# 迭代器对象从集合的第一个元素开始访问，直到所有元素被访问完毕，只能往前不能后退。
#
# 迭代器有两个基本方法```iter()```和```next()```

# %%
list=[1,2,3,4]
it=iter(list)
# print(next(it))
# print(next(it))
for x in it:
    print(x,end=" ")

# %% [markdown]
# 把一个类作为一个迭代器使用需要在类中实现两个方法```__iter__()```与```__next__()```，通过```StopIteration```异常标识迭代的完成。

# %%
class add1:
    def __iter__(self):
        self.a=1
        return self

    def __next__(self):
        if self.a<10:
            x=self.a
            self.a+=1
            return x
        else:
            raise StopIteration

# %%
import sys
myclass=add1()
myiter=iter(myclass)
while True:
    try:
        print(next(myiter))
    except StopIteration:
        print("woring")
        sys.exit()

# %%
# 试题：检查两个数中奇数和是否相等
def check(n1,n2):
    dif=0
    if(n1==n2==0):
        return 0
    elif(n1==0):
        dif=check(0,n2//10)
        if(n2%2==1):
            dif-=n2%10
    elif(n2==0):
        dif=check(n1//10,0)
        if(n1%2==1):
            dif+=n1%10
    else:
        dif=check(n1//10,n2//10)
        if(n1%2==1):
            dif+=n1%10
        if(n2%2==1):
            dif-=n2%10
    return(dif)
if __name__=='__main__':
    print(check(31581,3330641)==False)
